# %% [markdown]
# Assignment:
#
# Using SAGEMAKER STUDIO:
#
# **1) Write a notebook to read all CSV files in an S3 bucket**
#
# **2) Combine the files to read a single dataframe**
#
# 3) Apply native AWS algorithms from Sagemaker using
#
#     a) Autopilot (automated ml)
#     b) A loop into multiple algorithms and compare them. Use parallelism for data and models.
#
# 4) Select the best algorithm
#
# 5) Register the Model in Sagemaker
#
# 6) Ensure you are NOT using a single machine but a cluster to leverage parallelism

# %% [markdown]
# ### Import Necessary Libraries

# %%
# !pip install sagemaker
# Out:
# Collecting sagemaker
#   Downloading sagemaker-2.94.0.tar.gz (527 kB)
# Requirement already satisfied: attrs==20.3.0 in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3<2.0,>=1.20.21 in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (1.24.2)
# Collecting google-pasta
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (1.19.2)
# Collecting protobuf<4.0,>=3.1
#   Downloading protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Collecting protobuf3-to-dict<1.0,>=0.1.5
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting smdebug_rulesconfig==1.0.1
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (20.4)
# Requirement already satisfied: pandas in c:\users\itzsa\anaconda3\lib\site-packages (from sagemaker) (1.1.3)
# Collecting pathos
#   Downloading pathos-0.2.9-py3-none-any.whl (76 kB)
# Requirement already satisfied: botocore<1.28.0,>=1.27.2 in c:\users\itzsa\anaconda3\lib\site-packages (from boto3<2.0,>=1.20.21->sagemaker) (1.27.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\itzsa\anaconda3\lib\site-packages (from boto3<2.0,>=1.20.21->sagemaker) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\itzsa\anaconda3\lib\site-packages (from boto3<2.0,>=1.20.21->sagemaker) (1.0.0)
# Requirement already satisfied: six in c:\users\itzsa\anaconda3\lib\site-packages (from google-pasta->sagemaker) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\itzsa\anaconda3\lib\site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\itzsa\anaconda3\lib\site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\itzsa\anaconda3\lib\site-packages (from pandas->sagemaker) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\itzsa\anaconda3\lib\site-packages (from pandas->sagemaker) (2020.1)
# Collecting pox>=0.3.1
#   Downloading pox-0.3.1-py2.py3-none-any.whl (28 kB)
# Collecting dill>=0.3.5.1
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting multiprocess>=0.70.13
#   Downloading multiprocess-0.70.13-py38-none-any.whl (131 kB)
# Collecting ppft>=1.7.6.5
#   Downloading ppft-1.7.6.5-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\itzsa\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.2->boto3<2.0,>=1.20.21->sagemaker) (1.25.11)
# Building wheels for collected packages: sagemaker, protobuf3-to-dict
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-2.94.0-py2.py3-none-any.whl size=740776 sha256=2143f09efdf31cf8f6965d14adfd1e37b40e17df6865f57c63ac753cf8feae82
#   Stored in directory: c:\users\itzsa\appdata\local\pip\cache\wheels\fc\ad\ba\fcdaa7f0c926a0248e9c52e6ad2f54e44258608a4aaf83f984
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4033 sha256=44945a73602d12db01fd1dbc95c40c2306592345b5635d359643883aed6c736b
#   Stored in directory: c:\users\itzsa\appdata\local\pip\cache\wheels\fc\10\27\2d1e23d8b9a9013a83fbb418a0b17b1e6f81c8db8f53b53934
# Successfully built sagemaker protobuf3-to-dict
# Installing collected packages: google-pasta, protobuf, protobuf3-to-dict, smdebug-rulesconfig, pox, dill, multiprocess, ppft, pathos, sagemaker
# Successfully installed dill-0.3.5.1 google-pasta-0.2.0 multiprocess-0.70.13 pathos-0.2.9 pox-0.3.1 ppft-1.7.6.5 protobuf-3.20.1 protobuf3-to-dict-0.1.5 sagemaker-2.94.0 smdebug-rulesconfig-1.0.1

# %%
import os
import boto3

from smart_open import smart_open

import pandas as pd

import sagemaker
from sagemaker import get_execution_role

# %%
s3_client = boto3.client('s3',
                    aws_access_key_id= 'AKIAUSEODYLGWJHOFFVB',
                    aws_secret_access_key='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')
s3_bucket_name = 'myawsbucket-assignment'
s3 = boto3.resource('s3',
                    aws_access_key_id= 'AKIAUSEODYLGWJHOFFVB',
                    aws_secret_access_key='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')

# %%
filename = 'random-data.csv'

# %%
my_bucket = s3.Bucket(s3_bucket_name)

# combined_dataframe
data = pd.DataFrame(columns = ['x', 'y'])

for file in my_bucket.objects.filter(Prefix = 'csv/'):
    file_name = file.key
    if file_name.find(".csv") != -1:
        obj = s3_client.get_object(
            Bucket = s3_bucket_name,
            Key = file_name
        )
        
        print('='*30)
        print(file_name)
        print('='*30)
        
        this_file_data = pd.read_csv(obj['Body'])
        data = data.append(this_file_data)

        print(this_file_data)
print('='*30)
print("DATA OF ALL FILES COMBINED")
# Out:
# ==============================
# csv/file1.csv
# ==============================
#      x   y
# 0   95  93
# 1   15  84
# 2   11  29
# 3   53  95
# 4   19  84
# ..  ..  ..
# 65  79  33
# 66  87  60
# 67  15  96
# 68  46  17
# 69   1  27
#
# [70 rows x 2 columns]
# ==============================
# csv/file2.csv
# ==============================
#        x    y
# 0    932  431
# 1    219  988
# 2    974  972
# 3    260  990
# 4     65  561
# ..   ...  ...
# 245  356   25
# 246  542  782
# 247   79  290
# 248  899  909
# 249  197  788
#
# [250 rows x 2 columns]
# ==============================
# csv/file3.csv
# ==============================
#       x    y
# 0   433  108
# 1    83  518
# 2   703  174
# 3    99  168
# 4   472  638
# 5   742  654
# 6   309   66
# 7   427  326
# 8   365   62
# 9     2   86
# 10  167  742
# 11  118  569
# 12  247  282
# 13  572  187
# 14  320  520
# 15  177  142
# 16  163  705
# 17  394  433
# 18  725  742
# 19  408  463
# 20  780  485
# 21  666  151
# 22  183  217
# 23  328  692
# 24  121  305
# 25  454  287
# 26  296  477
# 27  395  553
# 28  694  506
# 29  219  441
# 30  117  315
# 31  600  529
# 32  148  415
# 33  539  201
# 34  734  487
# 35  660  741
# 36   41  466
# 37  629  223
# 38  671   12
# 39  425  573
# ==============================
# csv/file4.csv
# ==============================
#        x    y
# 0    169  388
# 1    330  407
# 2    161  255
# 3    430  444
# 4     99  442
# ..   ...  ...
# 115  173   85
# 116    4   15
# 117  478  163
# 118  126  405
# 119  332  408
#
# [120 rows x 2 columns]
# ==============================
# DATA OF ALL FILES COMBINED

# %%
# combined data
data
# Out:
#        x    y
# 0     95   93
# 1     15   84
# 2     11   29
# 3     53   95
# 4     19   84
# ..   ...  ...
# 115  173   85
# 116    4   15
# 117  478  163
# 118  126  405
# 119  332  408
#
# [480 rows x 2 columns]

# %%
data.to_csv(filename, index = False)
